# %% [markdown]
# # Scraping LADOT Volume Data from PDFs, Part 3
#
# ##### Where I Left Off
# In the first python notebook (Part 1), I described the problem and general approach I was taking to solve it. I downloaded all the manual count PDF documents and setup the file tables for later.
#
# In the second python notebook (Part 2), I described the process by which I was able to extract volume data from PDFs. I also described the general structure of each of the data tables. At this point, the resulting data has been converted to .csv files, formatted for data analysis.

# %%
### Setup
import csv
import glob
from datetime import datetime, date, time
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster
import os
import geopandas as gp

# %% [markdown]
# I'm going to start by loading and cleaning the tables provided by BOE. First there is the files table.

# %%
# Load traffic data files table
traffic_data_files_path = 'boe_tables/dbo_dot_traffic_data_files.csv'
dbo_dot_traffic_data_files = pd.read_csv(traffic_data_files_path,
                                         parse_dates=['UploadDT'],
                                         encoding="ISO-8859-1")

# Drop rows where TrafficID is NaN, convert TrafficID to int type
dbo_dot_traffic_data_files = dbo_dot_traffic_data_files.dropna(axis=0, how='any', subset=['TrafficID'])
dbo_dot_traffic_data_files['TrafficID'] = dbo_dot_traffic_data_files['TrafficID'].astype(int)

# Subset out Survey Data and Automatic Counts
dbo_dot_traffic_data_files = dbo_dot_traffic_data_files[(dbo_dot_traffic_data_files['TrafficType'] == 'manual_count')]

# See traffic data files head
print("There are " + str(len(dbo_dot_traffic_data_files)) + " records in the table.")
#dbo_dot_traffic_data_files.head()
dbo_dot_traffic_data_files[(dbo_dot_traffic_data_files['TrafficID'] == 1400)]
# Out:
# There are 9034 records in the table.
#          ID  TrafficID   TrafficType                       DocName  \
# 1636  19066       1400  manual_count  LaurelCanyon_Oxnard_2013.pdf
#
#      UniqueDocName            UploadDT
# 1636           NaN 2014-07-16 15:02:50

# %%
# Load traffic data table
traffic_data_path = 'boe_tables/dot_traffic_data.csv'
dot_traffic_data = pd.read_csv(traffic_data_path)

# Drop "ext" and "Shape" columns
dot_traffic_data = dot_traffic_data.drop(['ext','Shape'], axis=1)
#dot_traffic_data['IntersectionID'] = dot_traffic_data['IntersectionID'].astype(int)

# See traffic data head
dot_traffic_data.head()
dot_traffic_data[(dot_traffic_data['TrafficID'] == 1400)]
# Out:
#       TrafficID  IntersectionID    lat     lon                   intersection
# 1562       1400         24378.0  34.17 -118.43  BURBANK BLVD at HAZELTINE AVE

# %%
# Combine both of the traffic data files
file_table = dbo_dot_traffic_data_files.merge(dot_traffic_data,
                                              how='left',
                                              left_on='TrafficID',
                                              right_on='TrafficID')
file_table.head()
# Out:
#    ID  TrafficID   TrafficType                           DocName  \
# 0   1       1435  manual_count                    2_GRAVDM93.pdf
# 1   2       1436  manual_count                    4_CULVIS95.pdf
# 2   3       1436  manual_count                4_MONCUL100928.pdf
# 3   4       1437  manual_count  16_VISTA DEL MAR.WATERVIEW07.pdf
# 4   5       1437  manual_count                   16_visvis01.pdf
#
#                       UniqueDocName            UploadDT  IntersectionID  \
# 0                    2_GRAVDM93.pdf 2007-04-02 08:38:30           147.0
# 1                    4_CULVIS95.pdf 2008-02-20 09:15:12           168.0
# 2                4_MONCUL100928.pdf 2011-08-09 13:58:55           168.0
# 3  16_VISTA DEL MAR.WATERVIEW07.pdf 2007-11-28 13:01:46           169.0
# 4                   16_visvis01.pdf 2007-12-03 16:30:42           169.0
#
#      lat     lon                           intersection
# 0  33.95 -118.39    LA TIJERA BLVD AT SEPULVEDA EASTWAY
# 1  33.95 -118.39  WESTCHESTER PKWY AT SEPULVEDA EASTWAY
# 2  33.95 -118.39  WESTCHESTER PKWY AT SEPULVEDA EASTWAY
# 3  33.95 -118.44          PERSHING DR AT MANCHESTER AVE
# 4  33.95 -118.44          PERSHING DR AT MANCHESTER AVE

# %%
# Import output data tables
manualcount_df = pd.read_csv('TrafficCountData/Results/manualcount.csv')
pedestrian_df = pd.read_csv('TrafficCountData/Results/pedestrian.csv')
peakvol_df = pd.read_csv('TrafficCountData/Results/peakvol.csv')
specveh_df = pd.read_csv('TrafficCountData/Results/SpecialVehicle.csv')
info_df = pd.read_csv('TrafficCountData/Results/info.csv')

info_df.head()
# Out:
#    Unnamed: 0  count_id        date dayofweek district         hours  \
# 0           0        68  2011-04-25    MONDAY      YES  7-10AM 2-5PM
# 1           1        70  2011-09-08  THURSDAY      YES  7-10AM 2-5PM
# 2           2        89  2007-07-23    MONDAY      YES  7-10AM 3-6PM
# 3           3       112  2010-03-08    MONDAY      YES  7-10AM 2-5PM
# 4           4       142  2010-04-23    FRIDAY      YES  7-10AM 3-6PM
#
#   school_day     street_ew     street_ns weather
# 0        YES       65th PL   VAN NESS AV   SUNNY
# 1        YES  FLORENCE AV.    KANSAS AV.   SUNNY
# 2        YES   FLORENCE AV       WEST ST   SUNNY
# 3        YES       78TH ST  SAN PEDRO ST   SUNNY
# 4        YES       92ND ST     GRAHAM AV   SUNNY

# %%
# Left join the traffic data table to the count info table
info_df_merge = info_df.merge(file_table, how='left', left_on = 'count_id', right_on = 'ID')

# Take a look at the length and head of the new table
print(len(info_df_merge))
info_df_merge
# Out:
# 2119
#       Unnamed: 0  count_id        date  dayofweek district  \
# 0              0        68  2011-04-25     MONDAY      YES
# 1              1        70  2011-09-08   THURSDAY      YES
# 2              2        89  2007-07-23     MONDAY      YES
# 3              3       112  2010-03-08     MONDAY      YES
# 4              4       142  2010-04-23     FRIDAY      YES
# 5              5       151  2010-03-10  WEDNESDAY      YES
# 6              6       168  2009-06-08     MONDAY      YES
# 7              7       271  2009-11-02     MONDAY      YES
# 8              8       282  2013-04-30    TUESDAY      YES
# 9              9       321  2012-08-29  WEDNESDAY      YES
# 10            10       323  2009-03-02     MONDAY      YES
# 11            11       335  2009-02-26   THURSDAY      YES
# 12            12       362  2009-04-13     MONDAY      YES
# 13            13       503  2007-07-26   THURSDAY      YES
# 14            14       650  2010-03-24  WEDNESDAY      YES
# 15            15       685  2007-07-12   THURSDAY      YES
# 16            16     18169  2014-03-18    TUESDAY      YES
# 17            17     18241  2014-04-29    TUESDAY      YES
# 18            18     18273  2009-02-20     FRIDAY      YES
# 19            19     18289  2009-05-19    TUESDAY      YES
# 20            20     18321  2008-08-28   THURSDAY      YES
# 21            21     18336  2010-03-16    TUESDAY      YES
# 22            22     18237  2009-06-01     MONDAY      YES
# 23            23     18253  2008-10-23   THURSDAY      YES
# 19          7-10AM 3-6PM        YES              SILVER LAKE BL
# 20          7-10AM 3-6PM        YES                  MILBANK ST
# 21          7-10AM 3-6PM        YES               MIDDLEBURY ST
# 22          7-10AM 2-5PM        YES                  SLAUSON AV
# 23          7-10AM 3-6PM        YES                  MIRANDA ST
# 24          7-10AM 2-5PM        YES                     19TH ST
# 25          7-10AM 3-6PM        YES                WENTWORTH ST
# 26          7-10AM 2-5PM        YES                 SHERMAN WAY
# 27          7-10AM 3-6PM        YES                   SUNSET BL
# 28          7-10AM 3-6PM        YES               SUMMERLAND AV
# 29                7-10AM        YES                NATIONAL BL.
# ...                  ...        ...                         ...
# 2089        7-10AM 3-6PM        YES                  CLINTON ST
# 2090        7-10AM 2-5PM        YES                  CLINTON ST
# 2091        7-10AM 2-5PM        YES                  CLINTON ST
# 2092        7-10AM 3-6PM        YES                      6TH ST
# 2093        7-10AM 3-6PM        YES                RIVERSIDE DR
# 2094        7-10AM 3-6PM        YES               WASHINGTON BL
# 2095        7-10AM 3-6PM        YES                  CHANNEL ST
# 2096        7-10AM 2-5PM        YES                     59TH PL
# 2097        7-10AM 3-6PM        YES        CHALON RD (EAST LEG)
# 2098        7-10AM 2-5PM        YES                    103RD ST
# 2099        7-10AM 3-6PM        YES                 WILSHIRE BL
# 2100        7-10AM 3-6PM        YES                 WILSHIRE BL
# 2101        7-10AM 2-5PM        YES                 CHANDLER BL
# 2102        7-10AM 2-5PM        YES                STRATHERN ST
# 2103        7-10AM 3-6PM        YES                JEFFERSON BL
# 2104        7-10AM 3-6PM        YES                  OLYMPIC BL
# 2105        7-10AM 2-5PM        YES                 COHASSET ST
# 2106                 NaN        YES        1st ST. (Late Shift)
# 2107  7-9:30AM 12:30-3PM        YES       1ST ST. (Early Shift)
# 2108        7-10AM 3-6PM        YES                    YORK BL.
# 2109        7-10AM 3-6PM        YES                     5TH ST.
# 2110        7-10AM 3-6PM        YES              WASHINGTON BL.
# 2111        7-10AM 2-5PM        YES                  SLAUSON AV
# 2112        7-10AM 3-6PM        YES                  PERLITA AV
# 2113      10AM-1PM 3-6PM        YES                 MISSOURI AV
# 2114        7-10AM 3-6PM        YES                 MOORPARK ST
# 2115        7-10AM 2-5PM        YES  MONTAGUE ST / PARTHENIA ST
# 2116        7-10AM 3-6PM        YES                      1ST ST
# 2117        7-10AM 3-6PM        YES                 MISSOURI AV
# 2118        7-10AM 3-6PM        YES                     4th ST.
#
#                          street_ns weather     ID  TrafficID   TrafficType  \
# 0                      VAN NESS AV   SUNNY     68       1477  manual_count
# 1                       KANSAS AV.   SUNNY     70       1478  manual_count
# 2                          WEST ST   SUNNY     89       1493  manual_count
# 3                     SAN PEDRO ST   SUNNY    112       1510  manual_count
# 4                        GRAHAM AV   SUNNY    142       1530  manual_count
# 5                      FIGUEROA ST   SUNNY    151       1537  manual_count
# 6                        EVELYN AV   SUNNY    168       1549  manual_count
# 7                      SOMERSET DR   SUNNY    271         47  manual_count
# 8      BRONSON AV. / MALL DRIVEWAY   SUNNY    282         54  manual_count
# 9                     FIGUEROA ST.   SUNNY    321         89  manual_count
# 10                       FLOWER ST   SUNNY    323         91  manual_count
# 11                         HOPE ST   SUNNY    335         98  manual_count
# 12                      DACOTAH ST   SUNNY    362        116  manual_count
# 13                      FAIRFAX BL   SUNNY    503       2274  manual_count
# 14                          4TH AV   SUNNY    650        154  manual_count
# 15                     HIGHLAND AV   SUNNY    685        179  manual_count
# 16                    GLENDALE BL.   SUNNY  18169        472  manual_count
# 17                     HARVARD BL.   SUNNY  18241       7400  manual_count
# 18                  SILVER LAKE BL   SUNNY  18273       5631  manual_count
# 19                       TEVIOT ST   SUNNY  18289       7447  manual_count
# 20                     VAN NUYS BL   SUNNY  18321       4202  manual_count
# 21                 WESTMORELAND AV   SUNNY  18336       6019  manual_count
# 22                          7TH AV   SUNNY  18237       3869  manual_count
# 23                     WHITSETT AV   SUNNY  18253       7438  manual_count
# 24                       MEYLER ST   SUNNY  18360       5543  manual_count
# 25                      SHELDON ST   SUNNY  18446       7483  manual_count
# 26                      SHIRLEY AV   SUNNY  18469       7486  manual_count
# 27                 MICHELTORENA ST   SUNNY  18351       5052  manual_count
# 28                       MEYLER ST   SUNNY  18355       7270  manual_count
# 29                       MOTOR AV.   SUNNY  18489       5336  manual_count
# ...                            ...     ...    ...        ...           ...
# 2089                    JUANITA AV   SUNNY  15620       6846  manual_count
# 2090                   ROSSMORE AV   SUNNY  15628       5337  manual_count
# 2091                     WILTON PL   SUNNY  15632       4409  manual_count
# 2092                 CLOVERDALE AV   SUNNY  15634       6851  manual_count
# 2093                   CLYBOURN AV   SUNNY  15657       6862  manual_count
# 2094                    COCHRAN AV   SUNNY  15678       6872  manual_count
# 2095  PACIFIC AV / JOHNS GIBSON BL   SUNNY  15397       3778  manual_count
# 2096                    VERMONT AV   SUNNY  15429       5763  manual_count
# 2097        ROSCOMARE RD (ONE WAY)   SUNNY  15484       6799  manual_count
# 2098                     CLOVIS AV   SUNNY  15636       3972  manual_count
# 2099                 CLOVERDALE AV   SUNNY  15643       6856  manual_count
# 2100                    COCHRAN AV   SUNNY  15682       6873  manual_count
# 2101                 SUNNYSLOPE AV   SUNNY  15493       4564  manual_count
# 2102           CLEON AV / WHITE ST   SUNNY  15605       4443  manual_count
# 2103                    COCHRAN AV   SUNNY  15673       3929  manual_count
# 2104                    COCHRAN AV   SUNNY  15674       6869  manual_count
# 2105                    TUJUNGA AV   SUNNY  15690       6876  manual_count
# 2106                   ALAMEDA ST.   SUNNY  18130        898  manual_count
# 2107                   ALAMEDA ST.   SUNNY  18131        898  manual_count
# 2108                     AVENUE 64   SUNNY  18133       5615  manual_count
# 2109                  VAN NESS AV.   SUNNY  18134       5432  manual_count
# 2110                   WESTERN AV.   SUNNY  18170       2296  manual_count
# 2111                        6TH AV   SUNNY  18238       7432  manual_count
# 2112                MINNEAPOLIS ST   SUNNY  18259       7440  manual_count
# 2113                   WESTWOOD BL   SUNNY  17904       7358  manual_count
# 2114                    WOODMAN AV   SUNNY  17816       2120  manual_count
# 2115                    WOODMAN AV   SUNNY  17847       7348  manual_count
# 2116                 ST ANDREWS PL   SUNNY  17990       4390  manual_count
# 2117                   WESTWOOD BL   SUNNY  17903       7358  manual_count
# 2             1160.0  33.99 -118.28                    55TH ST at FIGUEROA ST
# 3             1543.0  33.96 -118.28                    79TH ST at FIGUEROA ST
# 4             2318.0  33.95 -118.28                    92ND ST at FIGUEROA ST
# 5             2675.0  33.90 -118.28              FIGUEROA ST AT ROSECRANS AVE
# 6             3203.0  33.79 -118.27             DOLORES ST at WILMINGTON BLVD
# 7             4922.0  34.02 -118.33             JEFFERSON BLVD AT SOMERSET DR
# 8             5009.0  34.01 -118.33                COLISEUM ST AT BRONSON AVE
# 9             5772.0  34.02 -118.27             FIGUEROA ST AT JEFFERSON BLVD
# 10            5794.0  34.01 -118.28                      37TH ST AT FLOWER ST
# 11            6036.0  34.01 -118.27                        HOPE ST AT 37TH ST
# 12            6143.0  34.02 -118.21                DACOTAH ST AT OLYMPIC BLVD
# 13            7251.0  34.05 -118.33                      9TH ST at HUDSON AVE
# 14            7848.0  34.03 -118.32                     4TH AVE at ADAMS BLVD
# 15            8116.0  34.05 -118.34                   12TH ST at HIGHLAND AVE
# 16           15000.0  34.10 -118.27                HYPERION AVE at ROWENA AVE
# 17           17960.0  33.74 -118.29               SEPULVEDA ST at MARSHALL CT
# 18            1449.0  33.97 -118.27                       BROADWAY at 73RD ST
# 19           13166.0  34.08 -118.36     ROSEWOOD AVE at CRESCENT HEIGHTS BLVD
# 20           15127.0  34.10 -118.23                DIVISION ST at CYPRESS AVE
# 21            2328.0  33.95 -118.26                    94TH ST at AVALON BLVD
# 22           17049.0  34.04 -118.40                ROXBURY DR at MONTE MAR DR
# 23           37589.0  34.30 -118.43               HUBBARD ST at DRONFIELD AVE
# 24            7463.0  34.05 -118.32                   10TH ST at WINDSOR BLVD
# 25           36541.0  34.23 -118.37                  TUXFORD ST at NORRIS AVE
# 26           37580.0  34.29 -118.44                 HUBBARD ST at HERRICK AVE
# 27           12349.0  33.99 -118.44               WALGROVE AVE at VENICE BLVD
# 28               NaN  34.05 -118.24     1st ST BETWEEN BROADWAY AND SPRING ST
# 29            4903.0  34.00 -118.32                        48TH ST at 8TH AVE
# ...              ...    ...     ...                                       ...
# 2089         42473.0  34.20 -118.39                 COVELLO ST at VANTAGE AVE
# 2090          1072.0  33.97 -118.32                        8TH AVE at 73RD ST
# 2091          7226.0  34.04 -118.35               BURNSIDE AVE at VENICE BLVD
# 2092         33315.0  34.22 -118.54              VANALDEN AVE at PARTHENIA ST
# 2093          6536.0  34.05 -118.38                     PICO BLVD at CREST DR
# 2094         45932.0  34.19 -118.37                    FAIR AVE at VANOWEN ST
# 2095         46310.0  34.12 -118.40       FRANKLIN CANYON DR at MULHOLLAND DR
# 2096         10999.0  33.98 -118.43            LA VILLA MARINA at ADMIRAL AVE
# 2097             NaN  34.30 -118.48  sepulveda bl. filtration plant drwy. # 3
# 2098         18539.0  34.07 -118.32              ROSEWOOD AVE at LUCERNE BLVD
# 2099         34527.0  34.24 -118.27              CREEMORE DR at CREEMORE LANE
# 2100         39671.0  34.19 -118.51                  ENCINO AVE at VANOWEN ST
# 2101         19523.0  34.09 -118.28               LEXINGTON AVE at VIRGIL AVE
# 2102          4802.0  34.00 -118.29                    42ND ST at VERMONT AVE
# 2103         18839.0  34.07 -118.29                       1ST ST at BIMINI PL
# 2104         10530.0  33.98 -118.45             VAN BUREN AVE at HARRISON AVE
# 2105         39642.0  34.19 -118.52               CHIMINEAS AVE at VANOWEN ST
# 2106          8958.0  34.05 -118.23                   ALAMEDA ST AT TEMPLE ST
# 2107          8958.0  34.05 -118.23                   ALAMEDA ST AT TEMPLE ST
# 2108           968.0  33.99 -118.30                     57TH ST at DENKER AVE
# 2109         10269.0  33.71 -118.30                     PATTON AVE at 27TH ST
# 2110          7420.0  34.05 -118.31                 LEEWARD AVE at NORTON AVE
# 2111             NaN  33.74 -118.29                    Grand btwn 1st and 2nd
# 2112         41730.0  34.20 -118.45                SHERMAN CIR at SHERMAN WAY
# 2113         51998.0  34.02 -118.51                 PACIFIC COAST HWY at E/LB
# 2114         35466.0  34.14 -118.43               WOODMAN AVE AT VENTURA BLVD
# 2115          8514.0  34.05 -118.26                    SHATTO ST at WITMER ST
# 2116         13964.0  34.03 -118.51         CHANNEL LANE at WEST CHANNEL ROAD
# 2117         51998.0  34.02 -118.51                 PACIFIC COAST HWY at E/LB
# 2118          8463.0  34.05 -118.26                        6TH ST at UNION DR
#
# [2119 rows x 20 columns]

# %%
# Import BOE Intersection spatial data
boe_int = gp.GeoDataFrame.from_file('shp/Intersections.shp')
# Take a peek at the table contents
boe_int.head()
# Out:
#    OBJECTID  ASSETID  CL_NODE_ID             X             Y        LAT  \
# 0      1001    96967       13589  6.392995e+06  1.839536e+06  34.045852
# 1      1002    96968       13634  6.406002e+06  1.841805e+06  34.052279
# 2      1003    96969       13660  6.398905e+06  1.841108e+06  34.050261
# 3      1004    96970       15007  6.480819e+06  1.861803e+06  34.108027
# 4      1005    96971       15024  6.479671e+06  1.861156e+06  34.106243
#
#           LON  TYPE CRTN_DT LST_MODF_D USER_ID              FROM_ST  \
# 0 -118.556794  None    None       None    None        PASEO MIRAMAR
# 1 -118.513895  None    None       None    None       VILLA WOODS PL
# 2 -118.537311  None    None       None    None           ALCIMA AVE
# 3 -118.267080  None    None       None    None  WEST SILVER LAKE DR
# 4 -118.270866  None    None       None    None             ANGUS ST
#
#            TO_ST                            TOOLTIP  ZIP_CODE  \
# 0     ESPERA AVE        PASEO MIRAMAR at ESPERA AVE   90272.0
# 1            D/E              VILLA WOODS PL at D/E   90272.0
# 2  LAS LOMAS AVE        ALCIMA AVE at LAS LOMAS AVE   90272.0
# 3     ROWENA AVE  WEST SILVER LAKE DR at ROWENA AVE   90039.0
# 4   PANORAMA TER           ANGUS ST at PANORAMA TER   90039.0
#
#                                              NLA_URL  \
# 0  navigatela/reports/intersection_report.cfm?pk=...
# 1  navigatela/reports/intersection_report.cfm?pk=...
# 2  navigatela/reports/intersection_report.cfm?pk=...
# 3  navigatela/reports/intersection_report.cfm?pk=...
# 4  navigatela/reports/intersection_report.cfm?pk=...
#
#                                        geometry
# 0  POINT (-118.5568057440078 34.04585714775025)
# 1   POINT (-118.5139074746574 34.0522839749969)
# 2   POINT (-118.5373235321818 34.0502655043602)
# 3   POINT (-118.267092077783 34.10803167807186)
# 2112        2112     18259  2010-04-29   THURSDAY      YES
# 2113        2113     17904  2008-03-10     MONDAY      YES
# 2114        2114     17816  2008-04-02  WEDNESDAY      YES
# 2115        2115     17847  2009-06-18   THURSDAY      YES
# 2116        2116     17990  2008-12-18   THURSDAY      YES
# 2117        2117     17903  2010-03-24  WEDNESDAY      YES
# 2118        2118     18001  2014-04-08    TUESDAY      YES
#
#                    hours school_day                   street_ew  \
# 0           7-10AM 2-5PM        YES                     65th PL
# 1           7-10AM 2-5PM        YES                FLORENCE AV.
# 2           7-10AM 3-6PM        YES                 FLORENCE AV
# 3           7-10AM 2-5PM        YES                     78TH ST
# 4           7-10AM 3-6PM        YES                     92ND ST
# 5           7-10AM 2-5PM        YES                    110TH ST
# 6           7-10AM 2-5PM        YES                    182ND ST
# 7           7-10AM 3-6PM        YES                JEFFERSON BL
# 8           7-10AM 3-6PM        YES                COLISEUM ST.
# 9           7-10AM 3-6PM        YES               JEFFERSON BL.
# 10          7-10AM 3-6PM        YES                     37TH ST
# 11          7-10AM 3-6PM        YES                     37TH ST
# 12          7-10AM 2-5PM        YES                  OLYMPIC BL
# 13          7-10AM 3-6PM        YES                  OLYMPIC BL
# 14                   NaN        YES                    ADAMS BL
# 15          7-10AM 3-6PM        YES                  OLYMPIC BL
# 16          7-10AM 3-6PM        YES               RIVERSIDE DR.
# 17          7-10AM 2-5PM        YES               CAMBRIDGE ST.
# 18          7-10AM 3-6PM        YES                 VAN PELT PL
# 19          7-10AM 3-6PM        YES              SILVER LAKE BL
# 20          7-10AM 3-6PM        YES                  MILBANK ST
# 21          7-10AM 3-6PM        YES               MIDDLEBURY ST
# 22          7-10AM 2-5PM        YES                  SLAUSON AV
# 23          7-10AM 3-6PM        YES                  MIRANDA ST
# 24          7-10AM 2-5PM        YES                     19TH ST
# 25          7-10AM 3-6PM        YES                WENTWORTH ST
# 26          7-10AM 2-5PM        YES                 SHERMAN WAY
# 27          7-10AM 3-6PM        YES                   SUNSET BL
# 28          7-10AM 3-6PM        YES               SUMMERLAND AV
# 29                7-10AM        YES                NATIONAL BL.
# ...                  ...        ...                         ...
# 2089        7-10AM 3-6PM        YES                  CLINTON ST
# 2090        7-10AM 2-5PM        YES                  CLINTON ST
# 2091        7-10AM 2-5PM        YES                  CLINTON ST
# 2092        7-10AM 3-6PM        YES                      6TH ST
# 2093        7-10AM 3-6PM        YES                RIVERSIDE DR
# 2094        7-10AM 3-6PM        YES               WASHINGTON BL
# 2095        7-10AM 3-6PM        YES                  CHANNEL ST
# 2096        7-10AM 2-5PM        YES                     59TH PL
# 2097        7-10AM 3-6PM        YES        CHALON RD (EAST LEG)
# 2098        7-10AM 2-5PM        YES                    103RD ST
# 2099        7-10AM 3-6PM        YES                 WILSHIRE BL
# 2100        7-10AM 3-6PM        YES                 WILSHIRE BL
# 2101        7-10AM 2-5PM        YES                 CHANDLER BL
# 2102        7-10AM 2-5PM        YES                STRATHERN ST
# 2103        7-10AM 3-6PM        YES                JEFFERSON BL
# 2104        7-10AM 3-6PM        YES                  OLYMPIC BL
# 2105        7-10AM 2-5PM        YES                 COHASSET ST
# 2106                 NaN        YES        1st ST. (Late Shift)
# 2107  7-9:30AM 12:30-3PM        YES       1ST ST. (Early Shift)
# 2108        7-10AM 3-6PM        YES                    YORK BL.
# 2109        7-10AM 3-6PM        YES                     5TH ST.
# 2110        7-10AM 3-6PM        YES              WASHINGTON BL.
# 2111        7-10AM 2-5PM        YES                  SLAUSON AV
# 2112        7-10AM 3-6PM        YES                  PERLITA AV
# 2113      10AM-1PM 3-6PM        YES                 MISSOURI AV
# 2114        7-10AM 3-6PM        YES                 MOORPARK ST
# 2115        7-10AM 2-5PM        YES  MONTAGUE ST / PARTHENIA ST
# 2116        7-10AM 3-6PM        YES                      1ST ST
# 2117        7-10AM 3-6PM        YES                 MISSOURI AV
# 2118        7-10AM 3-6PM        YES                     4th ST.
#
#                          street_ns weather  \
# 0                      VAN NESS AV   SUNNY
# 1                       KANSAS AV.   SUNNY
# 2                          WEST ST   SUNNY
# 3                     SAN PEDRO ST   SUNNY
# 4                        GRAHAM AV   SUNNY
# 5                      FIGUEROA ST   SUNNY
# 6                        EVELYN AV   SUNNY
# 7                      SOMERSET DR   SUNNY
# 8      BRONSON AV. / MALL DRIVEWAY   SUNNY
# 9                     FIGUEROA ST.   SUNNY
# 10                       FLOWER ST   SUNNY
# 11                         HOPE ST   SUNNY
# 12                      DACOTAH ST   SUNNY
# 13                      FAIRFAX BL   SUNNY
# 14                          4TH AV   SUNNY
# 15                     HIGHLAND AV   SUNNY
# 16                    GLENDALE BL.   SUNNY
# 17                     HARVARD BL.   SUNNY
# 18                  SILVER LAKE BL   SUNNY
# 19                       TEVIOT ST   SUNNY
# 20                     VAN NUYS BL   SUNNY
# 21                 WESTMORELAND AV   SUNNY
# 22                          7TH AV   SUNNY
# 23                     WHITSETT AV   SUNNY
# 24                       MEYLER ST   SUNNY
# 25                      SHELDON ST   SUNNY
# 26                      SHIRLEY AV   SUNNY
# 27                 MICHELTORENA ST   SUNNY
# 28                       MEYLER ST   SUNNY
# 29                       MOTOR AV.   SUNNY
# ...                            ...     ...
# 2089                    JUANITA AV   SUNNY
# 2090                   ROSSMORE AV   SUNNY
# 2091                     WILTON PL   SUNNY
# 2092                 CLOVERDALE AV   SUNNY
# 2093                   CLYBOURN AV   SUNNY
# 2094                    COCHRAN AV   SUNNY
# 2095  PACIFIC AV / JOHNS GIBSON BL   SUNNY
# 2096                    VERMONT AV   SUNNY
# 2097        ROSCOMARE RD (ONE WAY)   SUNNY
# 2098                     CLOVIS AV   SUNNY
# 2099                 CLOVERDALE AV   SUNNY
# 2100                    COCHRAN AV   SUNNY
# 2101                 SUNNYSLOPE AV   SUNNY
# 2102           CLEON AV / WHITE ST   SUNNY
# 2103                    COCHRAN AV   SUNNY
# 2104                    COCHRAN AV   SUNNY
# 2105                    TUJUNGA AV   SUNNY
# 2106                   ALAMEDA ST.   SUNNY
# 2107                   ALAMEDA ST.   SUNNY
# 2108                     AVENUE 64   SUNNY
# 2109                  VAN NESS AV.   SUNNY
# 2110                   WESTERN AV.   SUNNY
# 2111                        6TH AV   SUNNY
# 2112                MINNEAPOLIS ST   SUNNY
# 2113                   WESTWOOD BL   SUNNY
# 2114                    WOODMAN AV   SUNNY
# 2115                    WOODMAN AV   SUNNY
# 2116                 ST ANDREWS PL   SUNNY
# 2117                   WESTWOOD BL   SUNNY
# 2118                  VAN NESS AV.   SUNNY
#
#                           ...                       TYPE  CRTN_DT LST_MODF_D  \
# 0                         ...                       None     None       None
# 1                         ...                       None     None       None
# 2                         ...                       None     None       None
# 3                         ...                       None     None       None
# 4                         ...                       None     None       None
# 5                         ...                       None     None       None
# 6                         ...                       None     None       None
# 7                         ...                       None     None       None
# 8                         ...                       None     None       None
# 9                         ...                       None     None       None
# 10                        ...                       None     None       None
# 11                        ...                       None     None       None
# 12                        ...                       None     None       None
# 13                        ...                       None     None       None
# 14                        ...                       None     None       None
# 15                        ...                       None     None       None
# 16                        ...                       None     None       None
# 17                        ...                       None     None       None
# 18                        ...                       None     None       None
# 19                        ...                       None     None       None
# 20                        ...                       None     None       None
# 21                        ...                       None     None       None
# 22                        ...                       None     None       None
# 23                        ...                       None     None       None
# 24                        ...                       None     None       None
# 25                        ...                       None     None       None
# 26                        ...                       None     None       None
# 27                        ...                       None     None       None
# 28                        ...                        NaN      NaN        NaN
# 29                        ...                       None     None       None
# ...                       ...                        ...      ...        ...
# 2089                      ...                       None     None       None
# 2090                      ...                       None     None       None
# 2091                      ...                       None     None       None
# 2092                      ...                       None     None       None
# 2093                      ...                       None     None       None
# 2094                      ...                       None     None       None
# 2095                      ...                       None     None       None
# 2096                      ...                       None     None       None
# 2097                      ...                        NaN      NaN        NaN
# 2098                      ...                       None     None       None
# 2099                      ...                       None     None       None
# 2100                      ...                       None     None       None
# 2101                      ...                       None     None       None
# 2102                      ...                       None     None       None
# 2103                      ...                       None     None       None
# 2104                      ...                       None     None       None
# 2105                      ...                       None     None       None
# 2106                      ...                       None     None       None
# 2107                      ...                       None     None       None
# 2108                      ...                       None     None       None
# 2109                      ...                       None     None       None
# 2110                      ...                       None     None       None
# 2111                      ...                        NaN      NaN        NaN
# 2112                      ...                       None     None       None
# 2113                      ...                       None     None       None
# 2114                      ...                       None     None       None
# 2115                      ...                       None     None       None
# 2116                      ...                       None     None       None
# 2117                      ...                       None     None       None
# 2118                      ...                       None     None       None
#
#      USER_ID             FROM_ST                  TO_ST  \
# 0       None        FLORENCE AVE          ST ANDREWS PL
# 1       None         WESTERN AVE                78TH PL
# 2       None         FIGUEROA ST                55TH ST
# 3       None         FIGUEROA ST                79TH ST
# 4       None         FIGUEROA ST                92ND ST
# 5       None         FIGUEROA ST          ROSECRANS AVE
# 6       None     WILMINGTON BLVD             DOLORES ST
# 7       None         SOMERSET DR         JEFFERSON BLVD
# 8       None         COLISEUM ST            BRONSON AVE
# 9       None      JEFFERSON BLVD            FIGUEROA ST
# 10      None           FLOWER ST                37TH ST
# 11      None             HOPE ST                37TH ST
# 12      None        OLYMPIC BLVD             DACOTAH ST
# 13      None          HUDSON AVE                 9TH ST
# 14      None          ADAMS BLVD                4TH AVE
# 15      None        HIGHLAND AVE                12TH ST
# 16      None        HYPERION AVE             ROWENA AVE
# 17      None        SEPULVEDA ST            MARSHALL CT
# 18      None            BROADWAY                73RD ST
# 19      None        ROSEWOOD AVE  CRESCENT HEIGHTS BLVD
# 20      None         DIVISION ST            CYPRESS AVE
# 21      None             94TH ST            AVALON BLVD
# 22      None          ROXBURY DR           MONTE MAR DR
# 23      None          HUBBARD ST          DRONFIELD AVE
# 24      None             10TH ST           WINDSOR BLVD
# 25      None          TUXFORD ST             NORRIS AVE
# 26      None          HUBBARD ST            HERRICK AVE
# 27      None        WALGROVE AVE            VENICE BLVD
# 28       NaN                 NaN                    NaN
# 29      None             48TH ST                8TH AVE
# ...      ...                 ...                    ...
# 2089    None          COVELLO ST            VANTAGE AVE
# 2090    None             8TH AVE                73RD ST
# 2091    None        BURNSIDE AVE            VENICE BLVD
# 2092    None        VANALDEN AVE           PARTHENIA ST
# 2093    None           PICO BLVD               CREST DR
# 2094    None            FAIR AVE             VANOWEN ST
# 2095    None  FRANKLIN CANYON DR          MULHOLLAND DR
# 2096    None     LA VILLA MARINA            ADMIRAL AVE
# 2097     NaN                 NaN                    NaN
# 2098    None        ROSEWOOD AVE           LUCERNE BLVD
# 2099    None         CREEMORE DR          CREEMORE LANE
# 2100    None          ENCINO AVE             VANOWEN ST
# 2101    None       LEXINGTON AVE             VIRGIL AVE
# 2102    None             42ND ST            VERMONT AVE
# 2103    None              1ST ST              BIMINI PL
# 2104    None       VAN BUREN AVE           HARRISON AVE
# 2105    None       CHIMINEAS AVE             VANOWEN ST
# 2106    None           TEMPLE ST             JACKSON ST
# 2107    None           TEMPLE ST             JACKSON ST
# 2108    None             57TH ST             DENKER AVE
# 2109    None          PATTON AVE                27TH ST
# 2110    None          NORTON AVE            LEEWARD AVE
# 2111     NaN                 NaN                    NaN
# 2112    None         SHERMAN CIR            SHERMAN WAY
# 2113    None   PACIFIC COAST HWY                   E/LB
# 2114    None         WOODMAN AVE           VENTURA BLVD
# 2115    None                None                   None
# 2116    None        CHANNEL LANE      WEST CHANNEL ROAD
# 2117    None   PACIFIC COAST HWY                   E/LB
# 2118    None              6TH ST               UNION DR
#
#                                     TOOLTIP  ZIP_CODE  \
# 0             FLORENCE AVE at ST ANDREWS PL   90047.0
# 1                    WESTERN AVE at 78TH PL   90047.0
# 2                    FIGUEROA ST at 55TH ST   90037.0
# 3                    FIGUEROA ST at 79TH ST   90044.0
# 4                    FIGUEROA ST at 92ND ST   90003.0
# 5              FIGUEROA ST at ROSECRANS AVE   90248.0
# 6             WILMINGTON BLVD at DOLORES ST   90744.0
# 7             SOMERSET DR at JEFFERSON BLVD   90016.0
# 8                COLISEUM ST at BRONSON AVE   90008.0
# 9             JEFFERSON BLVD at FIGUEROA ST   90007.0
# 10                     FLOWER ST at 37TH ST   90007.0
# 11                       HOPE ST at 37TH ST   90007.0
# 12               OLYMPIC BLVD at DACOTAH ST   90023.0
# 13                     HUDSON AVE at 9TH ST   90019.0
# 14                    ADAMS BLVD at 4TH AVE   90018.0
# 15                  HIGHLAND AVE at 12TH ST   90019.0
# 16               HYPERION AVE at ROWENA AVE   90027.0
# 17              SEPULVEDA ST at MARSHALL CT   90731.0
# 18                      BROADWAY at 73RD ST   90003.0
# 19    ROSEWOOD AVE at CRESCENT HEIGHTS BLVD   90048.0
# 20               DIVISION ST at CYPRESS AVE   90065.0
# 21                   94TH ST at AVALON BLVD   90003.0
# 22               ROXBURY DR at MONTE MAR DR   90035.0
# 23              HUBBARD ST at DRONFIELD AVE   91342.0
# 24                  10TH ST at WINDSOR BLVD   90019.0
# 25                 TUXFORD ST at NORRIS AVE   91352.0
# 26                HUBBARD ST at HERRICK AVE   91342.0
# 27              WALGROVE AVE at VENICE BLVD   90066.0
# 28                                      NaN       NaN
# 29                       48TH ST at 8TH AVE   90043.0
# ...                                     ...       ...
# 2089              COVELLO ST at VANTAGE AVE   91605.0
# 2090                     8TH AVE at 73RD ST   90043.0
# 2091            BURNSIDE AVE at VENICE BLVD   90019.0
# 2092           VANALDEN AVE at PARTHENIA ST   91324.0
# 2093                  PICO BLVD at CREST DR   90035.0
# 2094                 FAIR AVE at VANOWEN ST   91606.0
# 2095    FRANKLIN CANYON DR at MULHOLLAND DR   90210.0
# 2096         LA VILLA MARINA at ADMIRAL AVE   90292.0
# 2097                                    NaN       NaN
# 2098           ROSEWOOD AVE at LUCERNE BLVD   90004.0
# 2099           CREEMORE DR at CREEMORE LANE   91042.0
# 2100               ENCINO AVE at VANOWEN ST   91406.0
# 2101            LEXINGTON AVE at VIRGIL AVE   90029.0
# 2102                 42ND ST at VERMONT AVE   90037.0
# 2103                    1ST ST at BIMINI PL   90004.0
# 2104          VAN BUREN AVE at HARRISON AVE   90291.0
# 2105            CHIMINEAS AVE at VANOWEN ST   91335.0
# 2106                TEMPLE ST at JACKSON ST   90012.0
# 2107                TEMPLE ST at JACKSON ST   90012.0
# 2108                  57TH ST at DENKER AVE   90062.0
# 2109                  PATTON AVE at 27TH ST   90731.0
# 2110              NORTON AVE at LEEWARD AVE   90005.0
# 2111                                    NaN       NaN
# 2112             SHERMAN CIR at SHERMAN WAY   91405.0
# 2113              PACIFIC COAST HWY at E/LB   90402.0
# 2114            WOODMAN AVE at VENTURA BLVD   91423.0
# 2115                                   None       NaN
# 2116      CHANNEL LANE at WEST CHANNEL ROAD   90402.0
# 2117              PACIFIC COAST HWY at E/LB   90402.0
# 2118                     6TH ST at UNION DR   90017.0
#
#                                                 NLA_URL  \
# 0     navigatela/reports/intersection_report.cfm?pk=832
# 1     navigatela/reports/intersection_report.cfm?pk=918
# 2     navigatela/reports/intersection_report.cfm?pk=...
# 3     navigatela/reports/intersection_report.cfm?pk=...
# 4     navigatela/reports/intersection_report.cfm?pk=...
# 5     navigatela/reports/intersection_report.cfm?pk=...
# 6     navigatela/reports/intersection_report.cfm?pk=...
# 7     navigatela/reports/intersection_report.cfm?pk=...
# 8     navigatela/reports/intersection_report.cfm?pk=...
# 9     navigatela/reports/intersection_report.cfm?pk=...
# 10    navigatela/reports/intersection_report.cfm?pk=...
# 11    navigatela/reports/intersection_report.cfm?pk=...
# 12    navigatela/reports/intersection_report.cfm?pk=...
# 13    navigatela/reports/intersection_report.cfm?pk=...
# 14    navigatela/reports/intersection_report.cfm?pk=...
# 15    navigatela/reports/intersection_report.cfm?pk=...
# 16    navigatela/reports/intersection_report.cfm?pk=...
# 17    navigatela/reports/intersection_report.cfm?pk=...
# 18    navigatela/reports/intersection_report.cfm?pk=...
# 19    navigatela/reports/intersection_report.cfm?pk=...
# 20    navigatela/reports/intersection_report.cfm?pk=...
# 21    navigatela/reports/intersection_report.cfm?pk=...
# 22    navigatela/reports/intersection_report.cfm?pk=...
# 23    navigatela/reports/intersection_report.cfm?pk=...
# 24    navigatela/reports/intersection_report.cfm?pk=...
# 25    navigatela/reports/intersection_report.cfm?pk=...
# 26    navigatela/reports/intersection_report.cfm?pk=...
# 27    navigatela/reports/intersection_report.cfm?pk=...
# 28                                                  NaN
# 29    navigatela/reports/intersection_report.cfm?pk=...
# ...                                                 ...
# 2089  navigatela/reports/intersection_report.cfm?pk=...
# 2090  navigatela/reports/intersection_report.cfm?pk=...
# 2091  navigatela/reports/intersection_report.cfm?pk=...
# 2092  navigatela/reports/intersection_report.cfm?pk=...
# 2093  navigatela/reports/intersection_report.cfm?pk=...
# 2094  navigatela/reports/intersection_report.cfm?pk=...
# 2095  navigatela/reports/intersection_report.cfm?pk=...
# 2096  navigatela/reports/intersection_report.cfm?pk=...
# 2097                                                NaN
# 2098  navigatela/reports/intersection_report.cfm?pk=...
# 2099  navigatela/reports/intersection_report.cfm?pk=...
# 2100  navigatela/reports/intersection_report.cfm?pk=...
# 2101  navigatela/reports/intersection_report.cfm?pk=...
# 2102  navigatela/reports/intersection_report.cfm?pk=...
# 2103  navigatela/reports/intersection_report.cfm?pk=...
# 2104  navigatela/reports/intersection_report.cfm?pk=...
# 2105  navigatela/reports/intersection_report.cfm?pk=...
# 2106  navigatela/reports/intersection_report.cfm?pk=...
# 2107  navigatela/reports/intersection_report.cfm?pk=...
# 2108  navigatela/reports/intersection_report.cfm?pk=968
# 2109  navigatela/reports/intersection_report.cfm?pk=...
# 2110  navigatela/reports/intersection_report.cfm?pk=...
# 2111                                                NaN
# 2112  navigatela/reports/intersection_report.cfm?pk=...
# 2113  navigatela/reports/intersection_report.cfm?pk=...
# 2114  navigatela/reports/intersection_report.cfm?pk=...
# 2115                                               None
# 2116  navigatela/reports/intersection_report.cfm?pk=...
# 2117  navigatela/reports/intersection_report.cfm?pk=...
# 2118  navigatela/reports/intersection_report.cfm?pk=...
#
#                                           geometry
# 0     POINT (-118.3111801675238 33.97457344728143)
# 1     POINT (-118.3090085639863 33.96816881798583)
# 2      POINT (-118.282681356782 33.99238429234652)
# 3     POINT (-118.2827015482146 33.96787104496666)
# 4     POINT (-118.2827013155509 33.95278864473218)
# 5     POINT (-118.2827605468675 33.90189835602986)
# 6     POINT (-118.2751224082636 33.79337025919423)
# 7      POINT (-118.337377284302 34.02557825898255)
# 8     POINT (-118.3339546752218 34.01823342519442)
# 9     POINT (-118.2799898748333 34.02192125171941)
# 10    POINT (-118.2810732071334 34.01782286953108)
# 11    POINT (-118.2793732658324 34.01707055140898)
# 12     POINT (-118.2122657696809 34.0209561887552)
# 13     POINT (-118.3341499438117 34.0590326935698)
# 14    POINT (-118.3212465349858 34.03263421964002)
# 15    POINT (-118.3414649799675 34.05332488291397)
# 16     POINT (-118.271397393021 34.10918499037699)
# 17    POINT (-118.2934063052298 33.74562121995081)
# 18    POINT (-118.2783103423573 33.97371172313098)
# 19    POINT (-118.3658778808947 34.08014399880637)
# 20    POINT (-118.2362701886821 34.10264503680527)
# 21    POINT (-118.2651569090316 33.95111178856816)
# 22    POINT (-118.4011003946886 34.04946065665198)
# 23     POINT (-118.433283958182 34.30479046946758)
# 24    POINT (-118.3253668305129 34.05563361498042)
# 25    POINT (-118.3752634169994 34.23166746262149)
# 26    POINT (-118.4422102323944 34.29683185284616)
# 27    POINT (-118.4462705914275 33.99714681029077)
# 28                                             NaN
# 29    POINT (-118.3257703887728 34.00003011318397)
# ...                                            ...
# 2089  POINT (-118.3980596818935 34.20730757978613)
# 2090  POINT (-118.3264760729207 33.97366030992684)
# 2091   POINT (-118.3563962529023 34.0442249627956)
# 2092  POINT (-118.5492051334232 34.22823386335201)
# 2093  POINT (-118.3873891165547 34.05527415013182)
# 2094  POINT (-118.3746923202441 34.19394531480285)
# 2095  POINT (-118.4069202524277 34.12896500996304)
# 2096  POINT (-118.4350898674488 33.98133467054345)
# 2097                                           NaN
# 2098  POINT (-118.3248506387877 34.07895243154242)
# 2099  POINT (-118.2709321124162 34.24543528508619)
# 2100  POINT (-118.5142233510574 34.19387947615564)
# 2101  POINT (-118.2865887938076 34.09346650877906)
# 2102   POINT (-118.291552053126 34.00731437290882)
# 2103  POINT (-118.2905231416642 34.07311660170816)
# 2104   POINT (-118.4517020382989 33.9891347797122)
# 2105  POINT (-118.5284098478581 34.19386591134311)
# 2106  POINT (-118.2380512146155 34.05107478485662)
# 2107  POINT (-118.2380512146155 34.05107478485662)
# 2108  POINT (-118.3044422297678 33.99058879401476)
# 2109  POINT (-118.3050049524281 33.71877646943712)
# 2110  POINT (-118.3181171530822 34.05898039131905)
# 2111                                           NaN
# 2112   POINT (-118.4515170787752 34.2011955332972)
# 2113    POINT (-118.5148250031088 34.025796323522)
# 2114  POINT (-118.4312392659329 34.14802590898114)
# 2115  POINT (-118.2661526978123 34.05458998835493)
# 2116  POINT (-118.5165949617979 34.03015480983458)
# 2117    POINT (-118.5148250031088 34.025796323522)
# 2118  POINT (-118.2688920393043 34.05689064894054)
#
# [2119 rows x 37 columns]

# %%
# Create new LA Basemap specifying map center, zoom level, and using Stamen Toner Tiles
count_map = folium.Map([34.109279, -118.266087],
                       tiles='Stamen Toner',
                       zoom_start=11)

# Subset out points with a NaN Coodinate values
info_df_merge = info_df_merge[pd.notnull(info_df_merge['LAT'])]
info_df_merge = info_df_merge[pd.notnull(info_df_merge['LON'])]

#marker_cluster = MarkerCluster().add_to(count_map)

locationlist = info_df_merge[['LAT','LON']].values.tolist()
labels = info_df_merge["DocName"].values.tolist()

print(len(labels))
print(len(locationlist))

# Loop through the midblock_points df, add each point and value for 'intersection' column to the map
#for point in range(len(locationlist)):
    #popup = folium.Popup(labels[point], parse_html=True)
    #folium.Marker(locationlist[point]
                  #,popup='test'
                 # 
                 #).add_to(count_map)
    #popup = folium.Popup(str(row['intersection']), parse_html=True)
    #popup issues. See here: https://github.com/python-visualization/folium/issues/726
    #folium.Marker([row['lat'], row['lon']]).add_to(marker_cluster)
for point in range(400):
    popup = folium.Popup(labels[point], parse_html=True)
    #popup = folium.Popup('hello')
    folium.Marker(locationlist[point], popup = popup).add_to(count_map)
# Show the map
count_map
# Out:
# 1987
# 1987
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
":{"0":"Valencia Street","1":"Valencia Street","2":"Valencia Street","3":"Market Street","4":"Haight Street","5":"Haight Street","6":"Market Street","7":"Market Street","8":"Market Street","9":"South Van Ness Avenue","10":null,"11":null,"12":null,"13":"Octavia Street","14":null,"15":"Mission Street","16":"Market Street","17":"Van Ness Avenue","18":"Market Street","19":null,"20":"Market Street","21":null,"22":"Sanchez Street","23":"Franklin Street","24":"Market Street","25":"Howard Street","26":"Fillmore Street","27":"Octavia Street","28":null}}'

df = pd.read_json(data)

location = df['Latitude'].mean(), df['Longitude'].mean()

import folium

#locationlist = df[["Latitude","Longitude"]].values.tolist()
#labels = df["Cafe Name"].values.tolist()

locationlist = info_df_merge[['LAT','LON']].values.tolist()
labels = info_df_merge["DocName"].values.tolist()

m = folium.Map(location=location, zoom_start=14)
for point in range(20):
    popup = folium.Popup(labels[point], parse_html=True)
    #popup = folium.Popup('hello')
    folium.Marker(locationlist[point], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# With the count file table built, I am going to use the filename to join to the traffic data files to get the count id. I'll start by loading in the traffic data files.
#
# All of the filenames from NavigateLA are in uppercase letters, so I'll change the filenames in my table to match.

# %%
# Load traffic data files table
traffic_data_files_path = 'data/TrafficCountFileStructure/boe_tables/dbo_dot_traffic_data_files.csv'
dbo_dot_traffic_data_files = pd.read_csv(traffic_data_files_path,
                                         parse_dates=['UploadDT'],
                                         encoding="ISO-8859-1")

# Drop rows where TrafficID is NaN, convert TrafficID to int type
dbo_dot_traffic_data_files = dbo_dot_traffic_data_files.dropna(axis=0, how='any', subset=['TrafficID'])
dbo_dot_traffic_data_files['TrafficID'] = dbo_dot_traffic_data_files['TrafficID'].astype(int)

# Subset out Survey Data and Automatic Counts
dbo_dot_traffic_data_files = dbo_dot_traffic_data_files[(dbo_dot_traffic_data_files['TrafficType'] == 'manual_count')]

# Uppercase the DocName in my table
dbo_dot_traffic_data_files['DocName'] = dbo_dot_traffic_data_files['DocName'].str.upper()

# Preview the table
print("There are " + str(len(dbo_dot_traffic_data_files)) + " records in the table.")
dbo_dot_traffic_data_files.head()
dbo_dot_traffic_data_files[(dbo_dot_traffic_data_files['DocName'] == 'DANIELS.PICO.170228-NDSMAN.PDF')]

# %% [markdown]
# Now I want to join count_files_df to dbo_dot_traffic_data_files. The result will be that each count record will have an intersection that it can be assigned to from the BOE City of Los Angeles file. For the join, I'm going to use the PDF filename.

# %%
# Within count files, subset out manual counts
count_files_manual = count_files_df[(count_files_df['type'] == 'manual')]

# Combine both of the traffic data files using inner join (so only include matches)
file_table = dbo_dot_traffic_data_files.merge(count_files_manual,
                                              how='inner',
                                              left_on='DocName',
                                              right_on='file')

# Exclude Mid-Block Values, convert to int
file_table = file_table[file_table['cl_node_id'] != 'Mid-Block']
file_table['cl_node_id'] = file_table['cl_node_id'].astype(int)

print("There are " + str(len(file_table)) + " records in the table.")
file_table.head()

# %% [markdown]
# Using the filename join, I was able to get 5750/9034 records matched. What about the rest?

# %%
# Peform outer join to find records that didn't match
file_table_nonmatch = dbo_dot_traffic_data_files.merge(count_files_manual,
                                                       how='outer',
                                                       left_on='DocName',
                                                       right_on='file')

file_table_nonmatch
